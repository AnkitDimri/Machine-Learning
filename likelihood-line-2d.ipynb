# %%
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

# %%
x = np.linspace (0, 10, 100)
y = 5*x + 50

# %%
plt.plot (x, y)

# %%
def loglikelihood (d, mu, w1, w0):
        
    l = 0
    for x, y in zip (d, mu):
            
        l += np.log (norm.pdf (w1*x + w0, y, 1))
        
    return l

# %%
w0 = np.linspace (0, 100, 200)
w1 = np.linspace (0, 10, 200)

W0, W1 = np.meshgrid (w0, w1)

# %%
ax = plt.axes(projection='3d')
fig = plt.figure()
ax.set_xlabel('W0')
ax.set_ylabel('W1')
ax.set_zlabel('Likelihood')

ax.plot_surface(W0, W1, loglikelihood (x, y, W1, W0), rstride=1, cstride=1,cmap='viridis', edgecolor='none')
ax.set_title('surface')
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in log
# Text(0.5, 0.92, 'surface')
# /home/ankit/.local/lib/python3.7/site-packages/matplotlib/colors.py:972: RuntimeWarning: invalid value encountered in subtract
#   resdat -= vmin
# /home/ankit/.local/lib/python3.7/site-packages/matplotlib/colors.py:973: RuntimeWarning: invalid value encountered in true_divide
#   resdat /= (vmax - vmin)
# /home/ankit/.local/lib/python3.7/site-packages/matplotlib/colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# /home/ankit/.local/lib/python3.7/site-packages/mpl_toolkits/mplot3d/proj3d.py:152: RuntimeWarning: invalid value encountered in true_divide
#   txs, tys, tzs = vecw[0]/w, vecw[1]/w, vecw[2]/w

# %%
plt.contour (W0, W1, loglikelihood (x, y, W1, W0))
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in log
